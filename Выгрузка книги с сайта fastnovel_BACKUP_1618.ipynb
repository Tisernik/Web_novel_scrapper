# %%
from random import seed
import requests

#url = "https://freewebnovel.com/lord-of-the-mysteries.html"
url = "https://www.wuxiaspot.com/novel/swallowed-star_1.html"
session_obj = requests.Session()
response = session_obj.get(url, headers={"User-Agent": "Mozilla/5.0"})
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">\r\n<head>\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=5.0" />\r\n<meta name="mobile-web-app-capable" content="yes" />\r\n\r\n<title>Swallowed Star |  Chapter 1: Luo Feng</title>\r\n<meta name="keywords" content="Swallowed Star | Chapter 1" />\r\n<meta name="description" content="Swallowed Star Novel Online  -  Chapter 1: Luo Feng" />\r\n\r\n<link rel="icon" href="/favicon.ico" type="image/x-icon">\r\n<link rel="stylesheet" type="text/css"  href="/static/css/696e8d1503a14010b3f90e68d6d10ae6.css"/>\r\n<link rel="stylesheet" type="text/css"  href="/static/css/google-fonts.css"/>\r\n<link rel="stylesheet" type="text/css"  href="/static/css/all.min.css?time=1734150898"/>\r\n<link rel="stylesheet" type="text/css"  href="/static/css/swiper.min.css"/>\r\n<link rel="stylesheet" type="text/css" href="/static/css/media-mobile.min.css" />\r\n<link rel="stylesheet" type="text/css" media="screen and (min-width: 768px)" href="/static/css/media-768.min.css" />\r\n<link rel="stylesheet" type="text/css" media="screen and (min-width: 1024px)" href="/static/css/media-1024.min.css" />\r\n<link rel="stylesheet" type="text/css" media="screen and (min-width: 1270px)" href="/static/css/media-1270.min.css" />\r\n<script src="/d/js/ad/adsense.js"></script>\r\n</head>\r\n<body class="fade-out">\r\n<header class="main-header skiptranslate">\r\n<div class="wrapper">\r\n<div class="nav-logo">\r\n<a title="Light Novels" href="/">\r\n<img src="/d/img/logo.png" alt="Web Novels" />\r\n</a>\r\n</div>\r\n<div class="navigation-bar" style="position: fixed; top: 0; right: 0; bottom: 0;">\r\n\r\n\r\n<nav>\r\n<span class="lnw-slog">Your Fictional Stories Hub.</span>\r\n<ul class="navbar-menu">\r\n <li class="nav-item">\r\n<a class="nav-link" title="Search Light Novels" href="/search.html"><i class="fas fa-search"></i> Search</a>\r\n</li>\r\n\r\n<li class="nav-item">\r\n<a class="drop-link" title="Explore the Most Popular Light Novels" href="/list/all/all-newstime-0.html"><i class="far fa-list-alt"></i> Categories</a>\r\n</li>\r\n\r\n<li class="nav-item">\r\n<a class="drop-link" title="Explore All Novel Tags" href="/browsetags/"><i class="fas fa-tags"></i> Tags</a>\r\n</li>\r\n\r\n<li class="nav-item">\r\n<a class="drop-link" title="Novels updated with new chapters" href="/updates/"><i class="fas fa-flag-checkered"></i> Updates</a>\r\n</li>\r\n\r\n<li class="nav-item">\r\n<a id="nightmode" data-tool="night" title="Night mode" data-night="0" data-content="Switch to Night Mode">\r\n<i class="fas fa-moon"></i>\r\n</a>\r\n\r\n\r\n</li>\r\n</ul>\r\n</nav>\r\n\r\n\r\n\r\n<div class="login-wrap-nav">\r\n<script src="/e/member/login/loginjs.php"></script>\r\n</div>\r\n</div>\r\n<div class="nav-back">\r\n</div>\r\n<i class="fas fa-bars mobile-nav-btn"></i>\r\n<span class="nav notify-bell mobile-block fa fa-bell"></span>\r\n</div>\r\n</header>\r\n\r\n<div class="sidebar-wrapper"></div>\r\n<main role="main">\r\n<article id="chapter-article">\r\n<div class="head-stick-offset"></div>\r\n<header class="chapter-header skiptranslate">\r\n<div class="content-wrap">\r\n<div class="titles">\r\n<h1><a href="/novel/swallowed-star.html" title="Swallowed Star">Swallowed Star</a></h1>\r\n<h2> Chapter 1: Luo Feng</h2>\r\n</div>\r\n<aside class="control-action" translate="no">\r\n<nav class="action-items">\r\n<div class="font-select">\r\n<div class="font-wrap">\r\n<input type="radio" id="radioDefault" name="radioFont" value="default" checked>\r\n<label for="radioDefault">Default</label>\r\n<input type="radio" id="radioDyslexic" name="radioFont" value="dyslexic">\r\n<label for="radioDyslexic">Dyslexic</label>\r\n<input type="radio" id="radioRoboto" name="radioFont" value="roboto">\r\n<label for="radioRoboto">Roboto</label>\r\n<input type="radio" id="radioLora" name="radioFon ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=5.0" name="viewport"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <title>Swallowed Star |  Chapter 1: Luo Feng</title>
# <meta content="Swallowed Star | Chapter 1" name="keywords"/>
# <meta content="Swallowed Star Novel Online  -  Chapter 1: Luo Feng" name="description"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/static/css/696e8d1503a14010b3f90e68d6d10ae6.css" rel="stylesheet" type="text/css">
# <link href="/static/css/google-fonts.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/all.min.css?time=1734150898" rel="stylesheet" type="text/css"/>
# <link href="/static/css/swiper.min.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/media-mobile.min.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/media-768.min.css" media="screen and (min-width: 768px)" rel="stylesheet" type="text/css"/>
# <link href="/static/css/media-1024.min.css" media="screen and (min-width: 1024px)" rel="stylesheet" type="text/css"/>
# <link href="/static/css/media-1270.min.css" media="screen and (min-width: 1270px)" rel="stylesheet" type="text/css"/>
# <script src="/d/js/ad/adsense.js"></script>
# </link></head>
# <body class="fade-out">
# <header class="main-header skiptranslate">
# <div class="wrapper">
# <div class="nav-logo">
# <a href="/" title="Light Novels">
# <img alt="Web Novels" src="/d/img/logo.png"/>
# </a>
# </div>
# <div class="navigation-bar" style="position: fixed; top: 0; right: 0; bottom: 0;">
# <nav>
# <span class="lnw-slog">Your Fictional Stories Hub.</span>
# <ul class="navbar-menu">
# <li class="nav-item">
# <a class="nav-link" href="/search.html" title="Search Light Novels"><i class="fas fa-search"></i> Search</a>
# </li>
# <li class="nav-item">
# <a class="drop-link" href="/list/all/all-newstime-0.html" title="Explore the Most Popular Light Novels"><i class="far fa-list-alt"></i> Categories</a>
# </li>
# <li class="nav-item">
# <a class="drop-link" href="/browsetags/" title="Explore All Novel Tags"><i class="fas fa-tags"></i> Tags</a>
# </li>
# <li class="nav-item">
# <a class="drop-link" href="/updates/" title="Novels updated with new chapters"><i class="fas fa-flag-checkered"></i> Updates</a>
# </li>
# <li class="nav-item">
# <a data-content="Switch to Night Mode" data-night="0" data-tool="night" id="nightmode" title="Night mode">
# <i class="fas fa-moon"></i>
# </a>
# </li>
# </ul>
# </nav>
# <div class="login-wrap-nav">
# <script src="/e/member/login/loginjs.php"></script>
# </div>
# </div>
# <div class="nav-back">
# </div>
# <i class="fas fa-bars mobile-nav-btn"></i>
# <span class="nav notify-bell mobile-block fa fa-bell"></span>
# </div>
# </header>
# <div class="sidebar-wrapper"></div>
# <main role="main">
# <article id="chapter-article">
# <div class="head-stick-offset"></div>
# <header class="chapter-header skiptranslate">
# <div class="content-wrap">
# <div class="titles">
# <h1><a href="/novel/swallowed-star.html" title="Swallowed Star">Swallowed Star</a></h1>
# <h2> Chapter 1: Luo Feng</h2>
# </div>
# <aside class="control-action" translate="no">
# <nav class="action-items">
# <div class="font-select">
# <div class="font-wrap">
# <input checked="" id="radioDefault" name="radioFont" type="radio" value="default"/>
# <label for="radioDefault">Default</label>
# <input id="radioDyslexic" name="radioFont" type="radio" value="dyslexic"/>
# <label for="radioDyslexic">Dyslexic</label>
# <input id="radioRoboto" name="radioFont" type="radio" value="roboto"/>
# <label for="radioRoboto">Roboto</label>
# <input id="radioLora" name="radioFont" type="radio" value="lora"/>
# <label for="radioLora">Lora</label>
# </div>
# </div>
# <div class="action-select notranslate">
# <a class="isDisabled chnav prev" href="javascript:;"><i class="material-icons">chevron_left</i><span>Prev</span></a>
# <a class="chnav next" href="/novel/swallowed-star_2.html" title=" Chapter 2: rr"><span>Next</span><i class="material-icons">chevron_right</i></a>
# <a data-tool="fontplus" title="Increase font size">
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24"><path clip-rule="evenodd" d="M20 2v3h3v2h-3v3h-2V7h-3V5h3V2h2zm-5.667 19l-1.703-4.6H5.37L3.667 21H1L7.667 3h2.666L17 21h-2.667zM9 6.6l2.74 7.4H6.26L9 6.6z" fill="#000" fill-rule="evenodd"></path></svg>
# </a>
# <a data-tool="fontminus" title="Decrease font size">
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24"><path clip-rule="evenodd" d="M14.333 21l-1.703-4.6H5.37L3.667 21H1L7.667 3h2.666L17 21h-2.667zM9 6.6l2.74 7.4H6.26L9 6.6zM23 5h-8v2h8V5z" fill="#000" fill-rule="evenodd"></path></svg>
# </a>
# <a data-night="0" data-tool="night" title="Night mode">
# <i class="material-icons">nights_stay</i>
# </a>
# </div>
# </nav>
# </aside>
# </div>
# </header>
# <section class="page-in content-wrap">
# <div class="left-panel">
# </div>
# <div class="chapter-content">
# <div align="center"><script src="/d/js/ad/page_01.js"></script></div>
# <p>Chapter 1 Luo Feng ("")</p><p>The sky is blue, it is like a huge blue jade, the summer sun is like a big fireball, hanging high in this huge emerald, watching the sun position, it is estimated that it will be around three in the afternoon.</p><p>The third high school in Yi'an District.</p><p>“Hey...” As the loud ringing bell rang through the campus, there was a buzzing sound throughout the campus, and a large number of students rushed through the school buildings, laughing in groups of three and five. go with.</p><p>"Luo Feng brother! Luo Feng brother!" A thick voice sounded.</p><p>"A Feng, someone called you."</p><p>Among the student population, the youth holding books with their classmates, wearing ordinary blue sportswear, is about one meter seventy-five in height and looks leaner. At this point, he was puzzled and turned to look at him. He was called a boy. His height was about one meter nine. He had a long tiger back and his arms were stout.</p><p>"You are?" Luo Feng was puzzled and looked at the people. He didn't seem to know the people in front of him.</p><p>These two, a strong one is like a black bear. And "Luo Feng brothers" and ordinary people in general.</p><p>On height...</p><p>These two people are very different. However, this boy with a bear-bearing waist is somewhat restrained. He carefully looked at the ‘Rofeng brothers’ he admired, and said: “It looks like the rumors are correct. Brother Luo Feng is very good at spe
h5>
# <div class="novel-stats">
# <span><i class="fas fa-medal"></i> Chapter 350</span>
# <span><i class="fas fa-clock"></i>11 hours ago</span>
# </div>
# </a>
# </li>
# <li class="novel-item">
# <a href="/novel/in-the-comprehensive-martial-arts-drawing-of-terms-every-time-it-is-a-must-to-hit-the-conceptual-le.html" title="In the comprehensive martial arts drawing of terms, every time it is a must to hit the conceptual le">
# <figure class="novel-cover">
# <img alt="In the comprehensive martial arts drawing of terms, every time it is a must to hit the conceptual le" class="lazy" data-src="/d/file/cover661/hepqiyegyyf.jpg" src="/static/picture/placeholder-158.jpg"/>
# </figure>
# <h5 class="novel-title text2row">In the comprehensive martial arts drawing of terms, every time it is a must to hit the conceptual le</h5>
# <div class="novel-stats">
# <span><i class="fas fa-medal"></i> Chapter 175</span>
# <span><i class="fas fa-clock"></i>11 hours ago</span>
# </div>
# </a>
# </li>
# </ul>
# </section>
# </article>
# </main>
# <footer translate="no">
# <div class="wrapper">
# <div class="col logo">
# <img alt="logo-footer" class="footer-logo" src="/d/img/logo.png"/>
# <span class="copyright">© 2024 WuxiaSpot.com</span>
# </div>
# <nav class="col links">
# <ul>
# <li>
# <a href="/list/all/all-onclick-0.html" title="Explore the Most Popular Light Novels">Most Popular</a>
# </li>
# <li>
# <a href="/updates/" title="Recently Updated Light Novel Chapters">Latest Chapters</a>
# </li>
# <li>
# <a href="/list/all/all-newstime-0.html" title="Latest Light Novels">Recent Novels</a>
# </li>
# <li><a href="/list/fan-fiction/all-newstime-0.html">Fan-Fiction</a></li>
# </ul>
# </nav>
# <nav class="col links">
# <ul>
# <li>
# <a href="/list/wuxia/all-newstime-0.html">Wuxia</a>
# </li>
# <li>
# <a href="/list/xianxia/all-newstime-0.html">Xianxia</a>
# </li>
# <li>
# <a href="/list/Xuanhuan/all-newstime-0.html">Xuanhuan</a>
# </li>
# <li>
# <a href="/list/fantasy/all-newstime-0.html">Fantasy</a>
# </li>
# </ul>
# </nav>
# <nav class="col links">
# <ul>
# <li>
# <a href="/list/romance/all-newstime-0.html">Romance</a>
# </li>
# <li>
# <a href="/list/urban/all-newstime-0.html">Urban</a>
# </li>
# <li>
# <a href="/list/action/all-newstime-0.html">Action</a>
# </li>
# <li>
# <a href="/browsetags/">All Tags</a>
# </li>
# </ul>
# </nav>
# <nav class="col links">
# <ul>
# <li>
# <a href="/privacy-policy.html">Privacy Policy</a>
# </li>
# <li>
# <a href="/terms-of-service.html">Terms of Service</a>
# </li>
# <li>
# <a href="/dmca.html">DMCA Notices</a>
# </li>
# <li>
# <a href="/contact-us.html">Contact Us</a>
# </li>
# </ul>
# </nav>
# </div>
# </footer>
# <div class="alertbox" id="alertbox_error">
# <div class="alert-wrapper">
# <div class="alert-body">
# <h6 class="title">Something Wrong!</h6>
# <div class="msg">
# Something Wrong!
# </div>
# </div>
# <button class="closebtn">
# <i class="fas fa-times"></i> Close
# </button>
# </div>
# </div>
# <div class="alertbox" id="alertbox_question">
# <div class="alert-wrapper">
# <div class="alert-body">
# <h6 class="title">Something Wrong!</h6>
# <div class="msg">
# Something Wrong!
# </div>
# </div>
# <div class="footer">
# <button class="closebtn">
# <i class="fas fa-times"></i> Cancel
# </button>
# <button class="apply">
# <i class="fas fa-times"></i> Apply
# </button>
# </div>
# </div>
# </div>
# <script src="/static/js/jquery.min.js"></script>
# <script src="/static/js/jquery.unobtrusive-ajax.min.js"></script>
# <script src="/static/js/sticky-kit.js"></script>
# <script src="/static/js/app.min.js"></script>
# <script src="/d/js/ad/footer.js"></script>
# <!--<script src="/static/js/app.min2.js"></script>-->
# <script src="/static/js/app-auth.min.js"></script>
# </body>
# </html>

# %%
aa = soup.find( class_ = "chapter-content" )
# Out:
# <p>Chapter 1 Luo Feng ("")</p>

# %%
# Вырезаем часть, в которой находятся ссылки на главы 
# при этом указаны ссылки не полностью, а только хвост, например "...href="/invincible-novel/chapter-1.html..."
a = soup.find_all("a", class_="chapter-content")
#print(a[3].get('href'))
#print(a[3])
print(a)
# Out:
# []

# %%
#novel_link = 'https://freewebnovel.com/invincible-novel.html'
novel_link = 'https://freewebnovel.com/lord-of-the-mysteries.html'
#Переменная либо для всех, либо для N последних, либо K первых глав

# %%
# Подключаем библиотеки
import requests 
import numpy as np
import io
import os
from bs4 import BeautifulSoup
from FB2 import FictionBook2, Author
from urllib import request
import time, sys
from IPython.display import clear_output

# %%
# Указываем страницу книги
# novel_link = 'https://freewebnovel.com/invincible-novel.html'
novel_link = 'https://freewebnovel.com/star-odyssey.html'

# !!! Переменная либо для всех, либо для N последних, либо K первых глав

# %%
# Получаем html-текст страницы
r = requests.get(novel_link)
html_text = r.text
soup = BeautifulSoup(html_text,'html.parser')

# Вырезаем часть, в которой находятся ссылки на главы 
# при этом указаны ссылки не полностью, а только хвост, например "...href="/invincible-novel/chapter-1.html..."
a = soup.find_all("ul", class_="ul-list5")
soup2 = BeautifulSoup(str(a),'html.parser')

# Получение хвостов ссылок на главы книги
soup_links = soup2.find_all("a", class_="con")

# Проверка:
#soup_links[0].get('href')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US"><head><title>Just a moment...</title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="noindex,nofollow" name="robots"/><meta content="width=device-width,initial-scale=1" name="viewport"/><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;max-width:60rem;padding-left:1.5rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{font-size:1.5rem;font-weight:500;line-height:2.25rem}@media (width <= 720px){.h2{font-size:1.25rem;line-height:1.5rem}}#challenge-error-text{background-image:url(data:image/svg+xml;base64,...);background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme:dark){body{background-color:#222;color:#d9d9d9}}</style><meta content="390" http-equiv="refresh"/></head><body class="no-js"><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt={cvId: '3',cZone: "freewebnovel.com",cType: 'managed',cRay: '8f2f4d546d8fbbbf',cH: 'Si9WxULTFLGxNKckEM1NuM0RsOlGnjuE77l.guAdvmY-1734358700-1.2.1.1-5Yc0zYiWNX3xOXu.AiKOQmr4x_o72UupaCl16q3mgWytRl4NwVBMVJbIhjRriABD',cUPMDTk: "\/star-odyssey.html?__cf_chl_tk=WG2N9FyuGU6bXvJJ21Gslt.RvbvzabDVKZx..Fr2Hw0-1734358700-1.0.1.1-SX2GWmLiIK8ruFux0D_gJ9jQj_8Ik4JBN3jEfgF5Fkw",cFPWv: 'g',cITimeS: '1734358700',cTTimeMs: '1000',cMTimeMs: '390000',cTplC: 0,cTplV: 5,cTplB: 'cf',cK: "",fa: "\/star-odyssey.html?__cf_chl_f_tk=WG2N9FyuGU6bXvJJ21Gslt.RvbvzabDVKZx..Fr2Hw0-1734358700-1.0.1.1-SX2GWmLiIK8ruFux0D_gJ9jQj_8Ik4JBN3jEfgF5Fkw",md: "xiIR86Ew3TZ3ABmrIovSQSoECjG2K.prc6RYNFW_4Qw-
JUE6GhfjnbID_yNY.VS4bVnEh08xz5rQ1OlBYpz1tpbDfO0pcC89y0ELGLrp.eMw_rsW9mYvNPZg.XHWBv4UXrUjlLb9_WE.j3nKavZ2q4oMnhwL6.zCPdB0iNcaCnjVV_DbkiCEwa82a1e.h4EhpEmly5p2ucCJFwlMoLjgPZFETJuxwI3qFFdG4vyk5YKyWIo1Zj2c6TOtvD4eVcAjRiY.1aii1g. ...

# %%
# Собираем список с реальными ссылками на главы книги
i = 1
chapter_link = []
garbage = []
for chapter in soup_links:
    href_link_string = chapter.get('href')
    chapter_last_link = href_link_string[18:] # вырезаем из текста "/invincible-novel/chapter-3753.html" крайнее значение "hapter-3753.html"
    chapter_link.append(novel_link[:-5]+"/"+chapter_last_link)

    garbage.append(href_link_string)

# В общем случе раскоментить
# Вырзем первые 6 ссылок из-за указания последних загруженных глав
#chapter_link = chapter_link[6:]

# Выгрузить последние главы
chapter_link = chapter_link[-200:]

# %%
chapter_link
# Out:
# []

# %%
# Проходимся по главам и достаем оттуда текст

chapters = []
chapters_ = []

errors = []

k = 0
for iter_chapter in chapter_link:
    time.sleep(1)
    #print(iter_chapter)
    
    req_chapter_link = requests.get(iter_chapter)
    chapter_html_text = req_chapter_link.text
    chapter_soup = BeautifulSoup(chapter_html_text,'html.parser')    
    chapter_soup_text = str(chapter_html_text)
     
    # вырезаю split-ом из-за того, что при "find_all" существеная часть текста пропадает
    # Сразу чистим от </p>
    chapter_soup_text = chapter_soup_text.replace("</p>", "")
    
    chapter_soup_text = chapter_soup_text.replace("<strong><u>", "")
    chapter_soup_text = chapter_soup_text.replace("</u></strong> ", "")

    chapter_soup_text = chapter_soup_text.replace("<h4>", "")
    chapter_soup_text = chapter_soup_text.replace("</h4>", "")

    chapter_soup_text = chapter_soup_text.replace("<b></b> ", "")

    chapter_soup_text = chapter_soup_text.replace("</div>", "")
    
    chapter_soup_text2 = chapter_soup_text.split("<div id=\"article\">")
    
    if len(chapter_soup_text2)>1:
        chapter_soup_text3 = chapter_soup_text2[1].split("<div class=\"notice-text\">")
        chapter_soup_text4 = chapter_soup_text3[0].split("<p>")
        ch_er = "Выполнение главы:" + iter_chapter
        errors.append(ch_er)
    else:
        print(iter_chapter)
        print(req_chapter_link)
        chapter_soup_text3 = ""
        chapter_soup_text4 = []
        ch_er = "!!! Проблемная глава:" + iter_chapter
        errors.append(ch_er)
    

    # вырезаем из строк типовое барахло "A day passed. <div style="margin-top: 0px; margin-botto%"
    new_txt = []
    for txt in chapter_soup_text4:
        txt_ = txt.split("<div style")

        # убираем пустые значения из списка абзацев в главе
        if txt_[0]!= "":
                 if txt != " ":
                     new_txt.append(txt_[0])
    
    chapters.append(new_txt)
    update_progress(k / len(chapter_link))
    print("Последняя глава:" + iter_chapter)
    k=k+1
# Out:
# Progress: [####################] 99.5%
# Последняя глава:https://freewebnovel.com/invincible-novel/chapter-3753.html

# %%
book = FictionBook2()

title = 'INVINCIBLE'
book.titleInfo.title = title
book.documentInfo.version = "1.1"

book.chapters = []

for i in chapters:
    book.chapters.append((i[0], i[1:]))

book.write(title + ".fb2")
